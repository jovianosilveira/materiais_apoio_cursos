# %% [markdown]
# <center><img width="70%" src="img/logo.png"></center>

# %% [markdown]
# # **Projeto Observatório Social - Prefeitura Municipal de Indaial / SC**
# ### <font color='#DC143C'> *Webcrapping com Python | Criação e Alimentação de DW*
# *by [JOVIANO SILVEIRA](https://www.joviano.com)*
#
# ---

# %% [markdown]
# # <font color=green> 1. MÃOS A MASSA

# %% [markdown]
# > Como já mencionamos, estou usando o navegador Chrome para este treinamento, e para que você consiga replicar, use o mesmo.
# >
# > Além disso, acesse o site [joviano.com](https://www.joviano.com) e "aperte" F12 em seu teclado.

# %% [markdown]
# <center><img width="100%" src="img/agente.png"></center>

# %%
# carregando variável com valor do "agente"
agente = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"

# %%
# Importando bibliotecas
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError
import bs4

# %% [markdown]
# > Vamos fazer agora a consulta de nossa página na WEB, mas vamos nos atentar a uns pontos extra (possiveis erros)

# %%
# endereço
url = "https://www.camaraindaial.sc.gov.br/pg/proposicoes"

# Carregue o agente que será usado na requisição
headers = {'User-Agent': agente}

# Efetuando a consulta SE NÃO TIVER ERRO NO LINK
try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    print(response.read())
    
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e: 
    print(e.reason)
# Out:
# b'\n\n<!DOCTYPE html>\n<html class="h-100">\n\t<head>\n\t\t\n\t\t<!--GENERAL-->\n\t\t<meta charset="utf-8">\n\t\t<meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n\t\t\n\t\t<!--PAGE TYPE-->\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="twitter:card"\n\t\t      content="summary_large_image">\n\t\t\n\t\t<!--TITLE-->\n\t\t\t\t<title>Proposi\xc3\xa7\xc3\xb5es   |  C\xc3\xa2mara Municipal de Indaial</title>\n\t\t<meta property="twitter:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t<meta property="og:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t\n\t\t<!--SUBTITLE-->\n\t\t<meta property="twitter:description" content="">\n\t\t<meta property="og:description" content="">\n\t\t\n\t\t<!--DESCRIPTION-->\n\t\t<meta property="description" content="Conte\xc3\xbado est\xc3\xa1tico com links para o Legislador.">\n\t\t\n\t\t<!--IMGS-->\n\t\t<meta property="twitter:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="twitter:image:alt" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="og:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t\n\t\t<!--YOUTUBE VIDEO-->\n\t\t\t\t\n\t\t<!--URL-->\n\t\t<link rel="canonical" href="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="og:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="twitter:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t\n\t\t\n\t\t\t\t\n\t\t<!--OFFICE-->\n\t\t\t\t\t<meta property="copyright" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:site_name" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:street-address"\n\t\t\t      content="Rua Prefeito Frederico Hardt, 148">\n\t\t\t<meta property="og:locality" content="Indaial">\n\t\t\t<meta property="og:region" content="Santa Catarina">\n\t\t\t<meta property="og:postal-code" content="89080-018">\n\t\t\t<meta property="og:country-name" content="Brazil">\n\t\t\t<meta property="og:email" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t<meta property="og:phonenumber" content="+55(47) 3380-6900">\n\t\t\t<meta property="reply-to" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t\t\n\t\t<!--CUSTOM-->\n\t\t<meta name="google-analytics" content=""/>\n\t\t<meta name="disqus" content=""/>\n\t\t\n\t\t<!-- CSS -->\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-application.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-utilities.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t\n\t\t<!-- Favicons -->\n\t\t<link rel="apple-touch-icon" sizes="57x57" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-57x57.png">\n\t\t<link rel="apple-touch-icon" sizes="72x72" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-72x72.png">\n\t\t<link rel="apple-touch-icon" sizes="76x76" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-76x76.png">\n\t\t<link rel="apple-touch-icon" sizes="114x114" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-114x114.png">\n\t\t<link rel="apple-touch-icon" sizes="120x120" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-120x120.png">\n\t\t<link rel="apple-touch-icon" sizes="144x144" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-144x144.png">\n\t\t<link rel="apple-touch-icon" sizes="152x152" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-152x152.png">\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-180x180.png">\n\t\t<link rel="icon" type="image/png" sizes="192x192" href="https ...

# %% [markdown]
# > No próximo teste, colocamos uma url de um dominio existente mas página não existe

# %%
# Endereço
url = "https://www.camaraindaial.sc.gov.br/joviano" 

# Carregue o agente que será usado na requisição
headers = {'User-Agent': agente}

# Efetuando a consulta SE NÃO TIVER ERRO NO LINK
try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    print(response.read())
    
except HTTPError as e:
    print('excessao 1 -> url não localizada')    
    print(e.status, e.reason)
    
except URLError as e: 
    print('excessao 2')
    print(e.reason)
# Out:
# excessao 1 -> url não localizada
# 404 Not Found

# %% [markdown]
# > Nesse teste estamos consultando um dominio e uma página que não existem

# %%
# Endereço
url = "https://www.camaraindaial.ZZ.gov.br/joviano" 

# Carregue o agente que será usado na requisição
headers = {'User-Agent': agente}

# Efetuando a consulta SE NÃO TIVER ERRO NO LINK
try:
    req = Request(url, headers = headers)
    response = urlopen(req)
    print(response.read())
    
except HTTPError as e:
    print('excessao 1 -> dominio existe, pagina não')    
    print(e.status, e.reason)
    
except URLError as e: 
    print('excessao 2 -> dominio não existe')
    print(e.reason)
# Out:
# excessao 2 -> dominio não existe
# [Errno 11001] getaddrinfo failed

# %% [markdown]
# > Fizemos três vezes o mesmo código, e aqui quero ensinar vocês a criar uma função, reduzindo assim o código nas futuras consultas

# %%
def ConsultaWeb(url):
    try:
        req = Request(url, headers = headers)
        response = urlopen(req)
        print(response.read())

    except HTTPError as e:
        print('excessao 1 -> dominio existe, pagina não')    
        print(e.status, e.reason)

    except URLError as e: 
        print('excessao 2 -> dominio não existe')
        print(e.reason)

# %%
# Olha como fica mais fácil
ConsultaWeb('https://www.camaraindaial.sc.gov.br/pg/proposicoes')
# Out:
# b'\n\n<!DOCTYPE html>\n<html class="h-100">\n\t<head>\n\t\t\n\t\t<!--GENERAL-->\n\t\t<meta charset="utf-8">\n\t\t<meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n\t\t\n\t\t<!--PAGE TYPE-->\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="twitter:card"\n\t\t      content="summary_large_image">\n\t\t\n\t\t<!--TITLE-->\n\t\t\t\t<title>Proposi\xc3\xa7\xc3\xb5es   |  C\xc3\xa2mara Municipal de Indaial</title>\n\t\t<meta property="twitter:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t<meta property="og:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t\n\t\t<!--SUBTITLE-->\n\t\t<meta property="twitter:description" content="">\n\t\t<meta property="og:description" content="">\n\t\t\n\t\t<!--DESCRIPTION-->\n\t\t<meta property="description" content="Conte\xc3\xbado est\xc3\xa1tico com links para o Legislador.">\n\t\t\n\t\t<!--IMGS-->\n\t\t<meta property="twitter:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="twitter:image:alt" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="og:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t\n\t\t<!--YOUTUBE VIDEO-->\n\t\t\t\t\n\t\t<!--URL-->\n\t\t<link rel="canonical" href="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="og:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="twitter:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t\n\t\t\n\t\t\t\t\n\t\t<!--OFFICE-->\n\t\t\t\t\t<meta property="copyright" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:site_name" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:street-address"\n\t\t\t      content="Rua Prefeito Frederico Hardt, 148">\n\t\t\t<meta property="og:locality" content="Indaial">\n\t\t\t<meta property="og:region" content="Santa Catarina">\n\t\t\t<meta property="og:postal-code" content="89080-018">\n\t\t\t<meta property="og:country-name" content="Brazil">\n\t\t\t<meta property="og:email" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t<meta property="og:phonenumber" content="+55(47) 3380-6900">\n\t\t\t<meta property="reply-to" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t\t\n\t\t<!--CUSTOM-->\n\t\t<meta name="google-analytics" content=""/>\n\t\t<meta name="disqus" content=""/>\n\t\t\n\t\t<!-- CSS -->\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-application.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-utilities.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t\n\t\t<!-- Favicons -->\n\t\t<link rel="apple-touch-icon" sizes="57x57" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-57x57.png">\n\t\t<link rel="apple-touch-icon" sizes="72x72" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-72x72.png">\n\t\t<link rel="apple-touch-icon" sizes="76x76" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-76x76.png">\n\t\t<link rel="apple-touch-icon" sizes="114x114" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-114x114.png">\n\t\t<link rel="apple-touch-icon" sizes="120x120" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-120x120.png">\n\t\t<link rel="apple-touch-icon" sizes="144x144" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-144x144.png">\n\t\t<link rel="apple-touch-icon" sizes="152x152" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-152x152.png">\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-180x180.png">\n\t\t<link rel="icon" type="image/png" sizes="192x192" href="https ...

# %%
def ConsultaWebB(url):
    try:
        req = Request(url, headers = headers)
        response = urlopen(req)
        return response.read()

    except:
        pass

# %%
# Tenta com um erro, se não der, passa...
ConsultaWebB('https://www.camaraindaial.sc.gov.br/joviano')

# %%
# Tenta com outro erro, se não der, passa...
ConsultaWebB('https://www.camaraindaial.ZZ.gov.br/joviano')

# %%
# Se o link estiver OK, ai sim os dados são retornados
ConsultaWebB('https://www.camaraindaial.sc.gov.br/pg/proposicoes')
# Out:
# b'\n\n<!DOCTYPE html>\n<html class="h-100">\n\t<head>\n\t\t\n\t\t<!--GENERAL-->\n\t\t<meta charset="utf-8">\n\t\t<meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n\t\t\n\t\t<!--PAGE TYPE-->\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="twitter:card"\n\t\t      content="summary_large_image">\n\t\t\n\t\t<!--TITLE-->\n\t\t\t\t<title>Proposi\xc3\xa7\xc3\xb5es   |  C\xc3\xa2mara Municipal de Indaial</title>\n\t\t<meta property="twitter:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t<meta property="og:title" content="Proposi\xc3\xa7\xc3\xb5es">\n\t\t\n\t\t<!--SUBTITLE-->\n\t\t<meta property="twitter:description" content="">\n\t\t<meta property="og:description" content="">\n\t\t\n\t\t<!--DESCRIPTION-->\n\t\t<meta property="description" content="Conte\xc3\xbado est\xc3\xa1tico com links para o Legislador.">\n\t\t\n\t\t<!--IMGS-->\n\t\t<meta property="twitter:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="twitter:image:alt" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t<meta property="og:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t\n\t\t<!--YOUTUBE VIDEO-->\n\t\t\t\t\n\t\t<!--URL-->\n\t\t<link rel="canonical" href="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="og:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t<meta property="twitter:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t\n\t\t\n\t\t\t\t\n\t\t<!--OFFICE-->\n\t\t\t\t\t<meta property="copyright" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:site_name" content="C\xc3\xa2mara Municipal de Indaial">\n\t\t\t<meta property="og:street-address"\n\t\t\t      content="Rua Prefeito Frederico Hardt, 148">\n\t\t\t<meta property="og:locality" content="Indaial">\n\t\t\t<meta property="og:region" content="Santa Catarina">\n\t\t\t<meta property="og:postal-code" content="89080-018">\n\t\t\t<meta property="og:country-name" content="Brazil">\n\t\t\t<meta property="og:email" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t<meta property="og:phonenumber" content="+55(47) 3380-6900">\n\t\t\t<meta property="reply-to" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t\t\n\t\t<!--CUSTOM-->\n\t\t<meta name="google-analytics" content=""/>\n\t\t<meta name="disqus" content=""/>\n\t\t\n\t\t<!-- CSS -->\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-application.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t<link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-utilities.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t\n\t\t<!-- Favicons -->\n\t\t<link rel="apple-touch-icon" sizes="57x57" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-57x57.png">\n\t\t<link rel="apple-touch-icon" sizes="72x72" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-72x72.png">\n\t\t<link rel="apple-touch-icon" sizes="76x76" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-76x76.png">\n\t\t<link rel="apple-touch-icon" sizes="114x114" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-114x114.png">\n\t\t<link rel="apple-touch-icon" sizes="120x120" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-120x120.png">\n\t\t<link rel="apple-touch-icon" sizes="144x144" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-144x144.png">\n\t\t<link rel="apple-touch-icon" sizes="152x152" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-152x152.png">\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-180x180.png">\n\t\t<link rel="icon" type="image/png" sizes="192x192" href="https ...

# %%
# Carregar uma variavel com conteudo da nossa consulta
html = ConsultaWebB('https://www.camaraindaial.sc.gov.br/pg/proposicoes')

# Quebrar o texto no sinal de menor
html.split('<')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-9ec611a8eff1> in <module>
#       3
#       4 # Quebrar o texto no sinal de menor
# ----> 5 html.split('<')
#
# TypeError: a bytes-like object is required, not 'str'

# %% [markdown]
# > Isso não foi possivel porque o objeto 'html' está no tipo bytes, e temos que transformar em texto para ai sim poder quebrar ele

# %%
# Carregar uma variavel com conteudo da nossa consulta
html = ConsultaWebB('https://www.camaraindaial.sc.gov.br/pg/proposicoes').decode('utf-8')

# Quebrar o texto no sinal de menor
html.split('<')
# Out:
# ['\n\n',
#  '!DOCTYPE html>\n',
#  'html class="h-100">\n\t',
#  'head>\n\t\t\n\t\t',
#  '!--GENERAL-->\n\t\t',
#  'meta charset="utf-8">\n\t\t',
#  'meta name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1">\n\t\t\n\t\t',
#  '!--PAGE TYPE-->\n\t\t',
#  'meta property="og:type" content="website">\n\t\t',
#  'meta property="twitter:card"\n\t\t      content="summary_large_image">\n\t\t\n\t\t',
#  '!--TITLE-->\n\t\t\t\t',
#  'title>Proposições   |  Câmara Municipal de Indaial',
#  '/title>\n\t\t',
#  'meta property="twitter:title" content="Proposições">\n\t\t',
#  'meta property="og:title" content="Proposições">\n\t\t\n\t\t',
#  '!--SUBTITLE-->\n\t\t',
#  'meta property="twitter:description" content="">\n\t\t',
#  'meta property="og:description" content="">\n\t\t\n\t\t',
#  '!--DESCRIPTION-->\n\t\t',
#  'meta property="description" content="Conteúdo estático com links para o Legislador.">\n\t\t\n\t\t',
#  '!--IMGS-->\n\t\t',
#  'meta property="twitter:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t',
#  'meta property="twitter:image:alt" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t',
#  'meta property="image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t',
#  'meta property="og:image" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg">\n\t\t\n\t\t',
#  '!--YOUTUBE VIDEO-->\n\t\t\t\t\n\t\t',
#  '!--URL-->\n\t\t',
#  'link rel="canonical" href="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t',
#  'meta property="og:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t',
#  'meta property="twitter:url" content="https://www.camaraindaial.sc.gov.br/pg/proposicoes">\n\t\t\n\t\t\n\t\t\t\t\n\t\t',
#  '!--OFFICE-->\n\t\t\t\t\t',
#  'meta property="copyright" content="Câmara Municipal de Indaial">\n\t\t\t',
#  'meta property="og:site_name" content="Câmara Municipal de Indaial">\n\t\t\t',
#  'meta property="og:street-address"\n\t\t\t      content="Rua Prefeito Frederico Hardt, 148">\n\t\t\t',
#  'meta property="og:locality" content="Indaial">\n\t\t\t',
#  'meta property="og:region" content="Santa Catarina">\n\t\t\t',
#  'meta property="og:postal-code" content="89080-018">\n\t\t\t',
#  'meta property="og:country-name" content="Brazil">\n\t\t\t',
#  'meta property="og:email" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t',
#  'meta property="og:phonenumber" content="+55(47) 3380-6900">\n\t\t\t',
#  'meta property="reply-to" content="secretaria@camaraindaial.sc.gov.br ">\n\t\t\t\t\n\t\t',
#  '!--CUSTOM-->\n\t\t',
#  'meta name="google-analytics" content=""/>\n\t\t',
#  'meta name="disqus" content=""/>\n\t\t\n\t\t',
#  '!-- CSS -->\n\t\t',
#  'link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-application.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t',
#  'link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-utilities.min.css?v=1.1" rel="stylesheet" type="text/css" media="screen"/>\n\t\t\n\t\t',
#  '!-- Favicons -->\n\t\t',
#  'link rel="apple-touch-icon" sizes="57x57" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-57x57.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="72x72" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-72x72.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="76x76" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-76x76.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="114x114" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-114x114.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="120x120" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-120x120.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="144x144" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-144x144.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="152x152" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-152x152.png">\n\t\t',
#  'link rel="apple-touch-icon" sizes="180x180" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-180x180.png">\n\t\t',
#  'link rel="icon" type="image/png" sizes="192x192" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/android-icon-192x192.png">\n\t\t',
#  'link rel="icon" type="image/png" sizes="32x32" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-32x32.png">\n\t\t',
#  'link rel="icon" type="image/png" sizes="96x96" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-96x96.png">\n\t\t',
#  'link rel="icon" type="image/png" sizes="16x16" href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-16x16.png">\n\t\t',
#  'meta name="msapplication-TileImage" content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/ms-icon-144x144.png">\n\t\t\n\t\t',
#  '!--Project Color for Mobile Browsers-->\n\t\t',
#  'meta name="msapplication-TileColor" content="#000">\n\t\t',
#  'meta name="theme-color" content="#000">\n\t\t\n\t\t',
#  '!--HEAD CODES-->\n\t\t',
#  '!-- Google Tag Manager -->\r\n',
#  "script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\r\nnew Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\r\n'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,'script','dataLayer','GTM-WBCNNX7');",
#  '/script>\r\n',
#  '!-- End Google Tag Manager -->\t\t\n\t\t\t',
#  '/head>\n',
#  'body>\n\t\n\t',
#  '!-- body inicio -->\r\n',
#  '!-- Google Tag Manager -->\r\n',
#  'noscript>\r\n     ',
#  'iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WBCNNX7" style="display:none; visibility:hidden">',
#  '/iframe>\r\n',
#  '/noscript>\r\n\n\n',
#  'header>\n\t',
#  'div class="container">\n\t\t\n\t\t',
#  '!--first line-->\n\t\t',
#  'div class="row align-center">\n\t\t\t\n\t\t\t',
#  'div class="col-6 col-4-md flex-center">\n\t\t\t\t\n\t\t\t\t',
#  '!--LOGOTYPE-->\n\t\t\t\t',
#  'a href="/home">\n\t\t\t\t\t',
#  'picture>\n\t\t\t\t\t\t',
#  '!--',
#  'source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/android-icon-48x48.png" media="(max-width:640px)"/>-->\n\t\t\t\t\t\t',
#  'img class="w-auto maxh-base-5 maxh-base-7-sm maxh-base-10-md"\n\t\t\t\t\t\t     src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/logotype.png"\n\t\t\t\t\t\t     alt="Câmara Municipal de Indaial"\n\t\t\t\t\t\t/>\n\t\t\t\t\t',
#  '/picture>\n\t\t\t\t',
#  '/a>\n\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t',
#  'div class="col-6 px-0 px-1-sm hides-md text-right">\n\t\t\t\t\n\t\t\t\t\t\t\n\t\t',
#  'button\n\t\t\ttype="button"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\thref="#busca"\n\t\t\t\t\t\t\n\t\t\tclass="btn btn--icon hides  "\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tjs-global-focus="#busca .search-bar__input"\t\t\t\t\t\t\t\n\t\t\taria-label="search"\n\t\t\trole="button"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon  " data-icon="search">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/button>\n\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t',
#  'button\n\t\t\ttype="button"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\thref="#menu"\n\t\t\t\t\t\t\n\t\t\tclass="btn btn--icon b-3 b-dark text-dark mx-1  "\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="menu"\n\t\t\trole="button"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon font-base " data-icon="menu">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/button>\n\t\n\t\t\t\t\n\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t',
#  'div class="col-8-md p-0 px-1-sm p-0-md nmb-1-md">\n\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t',
#  'i class="divider m-1 hides-md">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t\t',
#  'ul class="nav align-center justify-center-sm justify-end-md fw-bold font-small font-base-md font-2 flex-nowrap-md py-1-md pr-2-md">\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">\n\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\thref="/atendimento/acesso-a-informacao"\n\t\t\t\t\t\t\t\t\t\t\tclass="\n\t\t\t\t\t\t\t\t\t\t\t\tnav__link py-1 pl-1 pr-0 flex-center\n\t\t\t\t\t\t\t\t\t\t\t\tb-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbrand-text-primary-hfa\t\t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\t\taria-label="Acesso à informação"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t',
#  'picture class="">\n\t\t\t\t\t\t\t\t\t\t',
#  'source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink2.png" media="(max-width:412px)"/>\n\t\t\t\t\t\t\t\t\t\t\t',
#  'img class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink2.png" alt="" aria-label=""/>\n\t\t\t\t\t\t\t\t',
#  '/picture>\n\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t\t\t\t\t\t\t\t\tAcesso à informação\t\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  '/li>\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">\n\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\thref="/licitacoes-e-contratos"\n\t\t\t\t\t\t\t\t\t\t\tclass="\n\t\t\t\t\t\t\t\t\t\t\t\tnav__link py-1 pl-1 pr-0 flex-center\n\t\t\t\t\t\t\t\t\t\t\t\tb-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbrand-text-primary-hfa\t\t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\t\taria-label="Licitações e Contratos"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t',
#  'picture class="">\n\t\t\t\t\t\t\t\t\t\t',
#  'source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink1.png" media="(max-width:412px)"/>\n\t\t\t\t\t\t\t\t\t\t\t',
#  'img class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink1.png" alt="" aria-label=""/>\n\t\t\t\t\t\t\t\t',
#  '/picture>\n\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t\t\t\t\t\t\t\t\tLicitações e Contratos\t\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  '/li>\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">\n\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\thref="https://portalcamaraindaial.atende.net/#!/"\n\t\t\t\t\t\t\t\t\t\t\tclass="\n\t\t\t\t\t\t\t\t\t\t\t\tnav__link py-1 pl-1 pr-0 flex-center\n\t\t\t\t\t\t\t\t\t\t\t\tb-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbrand-text-primary-hfa\t\t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\t\taria-label="Portal da Transparência"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\ttarget="_blank"\n\t\t\t\t\t\t\t\t\t\t\t\trel="noreferrer"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t',
#  'picture class="">\n\t\t\t\t\t\t\t\t\t\t',
#  'source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink3.png" media="(max-width:412px)"/>\n\t\t\t\t\t\t\t\t\t\t\t',
#  'img class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink3.png" alt="" aria-label=""/>\n\t\t\t\t\t\t\t\t',
#  '/picture>\n\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t\t\t\t\t\t\t\t\tPortal da Transparência\t\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  '/li>\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">\n\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\thref="/atendimento"\n\t\t\t\t\t\t\t\t\t\t\tclass="\n\t\t\t\t\t\t\t\t\t\t\t\tnav__link py-1 pl-1 pr-0 flex-center\n\t\t\t\t\t\t\t\t\t\t\t\tb-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tbrand-text-primary-hfa\t\t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\t\taria-label="Ouvidoria &',
#  'br/>Carta de Serviços"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t',
#  'picture class="">\n\t\t\t\t\t\t\t\t\t\t',
#  'source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink4.png" media="(max-width:412px)"/>\n\t\t\t\t\t\t\t\t\t\t\t',
#  'img class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink4.png" alt="" aria-label=""/>\n\t\t\t\t\t\t\t\t',
#  '/picture>\n\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t\t\t\t\t\t\t\t\tOuvidoria &',
#  'br/>Carta de Serviços\t\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  '/li>\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t',
#  '/ul>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t',
#  '/div>\n\t',
#  '/div>\n\t\n\t\t\t\t',
#  'div class="float-container hides flex-md" style="margin-bottom: -1px;">\n\t\t\t\t',
#  'div class="container mr-0 py-0">\n\t\t\t\t\t',
#  'div class="row align-end">\n\t\t\t\t\t\t\n\t\t\t\t\t\t',
#  'div class="col-12 p-0 px-1-sm">\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="divider bb-3 my-0 mx-1 b-dark">',
#  '/i>\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'ul class="nav font-small font-base-md font-2 py-1-sm relative fw-regular justify-between">\n\t\t\t\t\t\t\t\t\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/institucional"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Institucional"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tInstitucional\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/vereadores"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Vereadores"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tVereadores\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/imprensa"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Imprensa"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tImprensa\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/agenda"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Agenda"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tAgenda\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/pautas"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Pautas"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tPautas\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/pg/legislacao"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Legislação"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tLegislação\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/pg/proposicoes"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Proposições  "\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tProposições  \t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/parlamento-jovem"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Parlamento Jovem"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tParlamento Jovem\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\n\t',
#  'li class="nav__item inline-block">\n\t\t',
#  'a\n\t\t\tclass="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1\n\t\t\t\t  b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa\n\t\t\t\t  dropdown__item\n\t                brand-text-primary-hfa mr-h"\n\t\t\thref="/atendimento"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="Fale conosco"\n\t\t>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'span class="bb-2 b-transparent brand-b-primary-lighter-a ">\n\t\t\t\t',
#  'span class="dropdown__clone">\n\t\t\t\t\tFale conosco\t\t\t\t',
#  '/span>\n\t\t\t',
#  '/span>\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t',
#  '/li>\n\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  '/ul>\n\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t',
#  '/div>\n\t\t\t',
#  '/header>\n\n\n',
#  'form id="busca" class="search-bar search-bar--fullscreen z-index-3" action="/pg/proposicoes" method="get">\n\t',
#  'div class="search-bar__vessel">\n\t\t',
#  'div class="search-bar__bar py-1 p-3-sm p-6-md">\n\t\t\t\n\t\t\t',
#  'i class="icon w-base-5 text-dark" data-icon="search">',
#  '/i>\n\t\t\t\n\t\t\t',
#  'div class="search-bar__content font-small font-base-md">\n\t\t\t\t',
#  'input type="search"\n\t\t\t\t       name="q"\n\t\t\t\t       class="search-bar__input h-base-5 h-base-6-sm fw-bold font-largex"\n\t\t\t\t       value=""\n\t\t\t\t       aria-label="Busca"\n\t\t\t\t/>\n\t\t\t\t',
#  'span class="search-bar__label text-italic mt-h-sm font-large-sm">O que você está procurando?',
#  '/span>\n\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t\t\t\n\t\t',
#  'button\n\t\t\ttype="reset"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\tclass="btn btn--icon  "\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\taria-label="Resetar"\t\t\t\t\t\t\t\n\t\t\taria-label="close"\n\t\t\trole="button"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="close">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/button>\n\t\n\t\t\t',
#  '/div>\n\t\t\n\t\t\t',
#  '/div>\n\t',
#  'button type="button" class="scrimmer" aria-label="Fechar">',
#  '/button>\n\n',
#  '/form>',
#  '!--drawer nav-->\n\n',
#  'div id="menu" class="drawer">\n\t',
#  'div class="drawer__vessel maxw-unit-6">\n\t\t',
#  'div class="drawer__content py-0">\n\t\t\t\n\t\t\t',
#  'div class="flex">\n\t\t\t\t\t\t\n\t\t',
#  'button\n\t\t\ttype="button"\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\tclass="btn btn--icon text-icon mx-1 my-1  "\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tjs-dismiss=".drawer"\t\t\t\t\t\t\t\t\tjs-dismiss-hash=""\t\t\t\t\t\t\t\t\taria-label="Fechar"\t\t\t\t\t\t\t\n\t\t\taria-label="long-arrow-left"\n\t\t\trole="button"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="long-arrow-left">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/button>\n\t\n\t\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t',
#  'div class="flex flex-column fw-bold font-base pb-6 divider-group-last font-2">\n\t\t\t\t\n\t\t\t\t',
#  'div class="font-1 mb-2 flex flex-column align-start p-2" style="background-color: #f5f5f5;">\n\t\t\t\t\t\t\t\n\t\t',
#  'a\n\t\t\t\t\t\t\n\t\t\thref="tel:4733806900"\n\t\t\tclass="btn btn--raised btn--primary btn--inverse w-100 text-initial font-base py-1 px-2 b-1tooltiper  "\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tnojs=""\t\t\t\t\t\t\t\t\tjs-copyphone-trigger="this"\t\t\t\t\t\t\t\t\tjs-copyphone-target="(47) 3380-6900"\t\t\t\t\t\t\t\t\ttitle="Das 8h30 &agrave;s 20h30"\t\t\t\t\t\t\t\t\tdata-action=""\t\t\t\t\t\t\t\n\t\t\taria-label="(47) 3380-6900"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon font-large " data-icon="phone">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'span class="btn__label  ">\n\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t(47) 3380-6900\t\t\t\t',
#  '/span>\n\t\t\t\t\t',
#  '/a>\n\t\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="institucional1"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/institucional"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Institucional"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tInstitucional\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#institucional1"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/institucional/historia"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="História"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tHistória\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/institucional/escola-do-legislativo"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Escola do Legislativo"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tEscola do Legislativo\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/institucional/regimento-interno"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Regimento Interno"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tRegimento Interno\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/institucional/lei-organica"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Lei Orgânica"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tLei Orgânica\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/institucional/perguntas-frequentes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Perguntas Frequentes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tPerguntas Frequentes\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="vereadores2"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/vereadores"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Vereadores"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tVereadores\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#vereadores2"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/vereadores/vereadores"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Vereadores"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tVereadores\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/vereadores/mesa-diretora"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Mesa Diretora"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tMesa Diretora\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/vereadores/comissoes-permanentes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Comissões Permanentes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tComissões Permanentes\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="imprensa3"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/imprensa"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Imprensa"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tImprensa\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#imprensa3"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/imprensa/noticias"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Notícias"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tNotícias\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/imprensa/sessoes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Resumo das sessões"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tResumo das sessões\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/imprensa/atas-das-sessoes"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Atas das Sessões"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tAtas das Sessões\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/imprensa/galeria-de-imagens"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Galeria de imagens"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tGaleria de imagens\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="divider-after">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/agenda"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\taria-label="Agenda"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tAgenda\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="pautas5"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/pautas"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Pautas"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tPautas\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#pautas5"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="https://www.camaraindaial.sc.gov.br/pautas/sessao-ordinaria"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Sess&atilde;o Ordin&aacute;ria"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tSess&atilde;o Ordin&aacute;ria\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="divider-after">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/pg/legislacao"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\taria-label="Legislação"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tLegislação\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="divider-after">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/pg/proposicoes"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   active"\n\t\t\t\t\t\t\t\t\t\taria-label="Proposições  "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tProposições  \t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="parlamento-jovem8"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/parlamento-jovem"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Parlamento Jovem"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tParlamento Jovem\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#parlamento-jovem8"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/parlamento-jovem/noticias-jovem"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Notícias"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tNotícias\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/parlamento-jovem/galeria-de-imagens-jovem"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Galeria de imagens"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tGaleria de imagens\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  'div class="divider-after collapse__item">\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'input\n\t\t\t\t\t\t\t\t\ttype="checkbox"\n\t\t\t\t\t\t\t\t\tclass="collapse__input"\n\t\t\t\t\t\t\t\t\tid="atendimento9"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t/>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="relative">\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\thref="/atendimento"\n\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1\n\t\t\t\t\t\t\t\t\t\t\t   brand-bg-secondary-lighter-a ripple\n\t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t\t   \t\t\t\t\t\t\t\t\t\t"\n\t\t\t\t\t\t\t\t\t\taria-label="Fale conosco"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'span>\n\t\t\t\t\t\t\t\t\t\t\tFale conosco\t\t\t\t\t\t\t\t\t\t',
#  '/span>\n\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t',
#  'button class="btn btn--icon flex-noshrink absolute-tr"\n\t\t\t\t\t\t\t\t\t        js-global-toggle-check="#atendimento9"\n\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  'i\n\t\t\t\t\t\t\t\t\t\t\tclass="icon collapse__icon text-dark"\n\t\t\t\t\t\t\t\t\t\t\tdata-icon="chevron-down"\n\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t',
#  '/i>\n\t\t\t\t\t\t\t\t\t',
#  '/button>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t',
#  'div class="collapse__vessel">\n\t\t\t\t\t\t\t\t\t',
#  'div class="collapse__content pb-2">\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/atendimento/ouvidoria"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Ouvidoria"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tOuvidoria\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/atendimento/carta-de-servicos"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Carta de Serviços"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tCarta de Serviços\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/atendimento/acesso-a-informacao"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Acesso à informação"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tAcesso à informação\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tclass="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t   "\n\t\t\t\t\t\t\t\t\t\t\t\t\t\thref="/atendimento/fale-conosco"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tstyle="white-space: normal"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\taria-label="Fale Conosco"\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\tFale Conosco\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t',
#  'div class="py-2 px-h">\n\t\t\t\t\t\t\t\n\t\t',
#  'a\n\t\t\t\t\t\t\n\t\t\thref="https://www.instagram.com/camaraindaial/"\n\t\t\tclass="btn btn--icon btn--primary w-base-6 h-base-6  "\n\t\t\t\n\t\t\t\t\t\t\ttarget="_blank"\n\t\t\t\trel="noreferrer"\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="instagram"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="instagram">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t\n\t\t\t\n\t\t',
#  'a\n\t\t\t\t\t\t\n\t\t\thref="https://www.facebook.com/camaraindaial/"\n\t\t\tclass="btn btn--icon btn--primary w-base-6 h-base-6  "\n\t\t\t\n\t\t\t\t\t\t\ttarget="_blank"\n\t\t\t\trel="noreferrer"\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="facebook-box"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="facebook-box">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t\n\t\t\t\n\t\t',
#  'a\n\t\t\t\t\t\t\n\t\t\thref="#/"\n\t\t\tclass="btn btn--icon btn--primary w-base-6 h-base-6  "\n\t\t\t\n\t\t\t\t\t\t\ttarget="_blank"\n\t\t\t\trel="noreferrer"\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="youtube-play"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="youtube-play">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t\n\t\t\t\n\t\t',
#  'a\n\t\t\t\t\t\t\n\t\t\thref="#/"\n\t\t\tclass="btn btn--icon btn--primary w-base-6 h-base-6  "\n\t\t\t\n\t\t\t\t\t\t\ttarget="_blank"\n\t\t\t\trel="noreferrer"\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\taria-label="linkedin"\n\t\t\t\n\t\t\t\t\t>\n\t\t\t\n\t\t\t\t\t\t\t',
#  'i class="icon icon--3 " data-icon="linkedin">',
#  '/i>\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/a>\n\t\n\t\t\t\t\t',
#  '/div>\n\t\t\t',
#  '/div>\n\t\t\n\t\t',
#  '/div>\n\t',
#  '/div>\n\t',
#  'button type="button" class="scrimmer" aria-label="Fechar">',
#  '/button>\n',
#  '/div>\t\n\t\t\n\t',
#  '!--CONTENT-->\n\t\n',
#  'div class="relative bt-1">\n\t',
#  'div class="absolute h-100 w-100 overflow-hidden" style="top:0; left:0;">\n\t\t',
#  'div class="absolute" style="top:50%; left:0; transform: translateY(-50%);">\n\t\t\t\n\t\t\t\t\t\t\n\t\t\t',
#  'picture class="">\n\t\t\t\t\t\t\t',
#  '/picture>\n\t\t\n\t\t\t\t',
#  '/div>\n\t',
#  '/div>\n\t\n\t',
#  'div class="container">\n\t\t',
#  'div class="row">\n\t\t\t',
#  'div class="col-12 flex-column py-4-sm py-8-md relative z-index-1 text-center">\n\t\t\t\t\n\t\t\t\t',
#  'div class="nmt-2-md nmx-2">\n\t\t\t\t\t\t\t\n\t\t',
#  'nav class="breadcrumb text-uppercase fw-bold font-2 flex-center-center">\n\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\thref="/home"\n\t\t\t\t\t\t\tclass="breadcrumb__item   "\n\t\t\t\t\t\t>\n\t\t\t\t\t\t\tHome\t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t\t\t\t\t',
#  'a\n\t\t\t\t\t\t\thref="/pg/proposicoes"\n\t\t\t\t\t\t\tclass="breadcrumb__item active hides  "\n\t\t\t\t\t\t>\n\t\t\t\t\t\t\tProposições  \t\t\t\t\t\t',
#  '/a>\n\t\t\t\t\t\t\t',
#  '/nav>\n\t\t\t\t\t\t',
#  '/div>\n\t\t\t\t\n\t\t\t\t',
#  'div class="nmt-2 mt-0-md">\n\t\t\t\t\t\t\t\n\t\t',
#  'div class=" ">\n\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t',
#  'div class=" font-2 fw-bold h6 h5-sm h2-md lh-small nletter-1 text-dark">\n\t\t\t\t\t\tProposições  \t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t',
#  '/div>\n\t\t\t\t\t\t',
#  '/div>\n\t\t\t\n\t\t\t',
#  '/div>\n\t\t',
#  '/div>\n\t',
#  '/div>\n',
#  '/div>\n\n\t\n\t',
#  'section class="bt-1">\n\t\t',
#  'div class="container img-load px-2-md py-6-md">\n\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t',
#  'div class="row justify-center">\n\t\t\t\t\t\t',
# ...
#  '= top) {\n                    continue;\n                }\n                if (currentHash == p.hash) {\n                    break;\n                }\n                var scrollTop = $(document).scrollTop();\n\n                //  update current hash\n                currentHash = p.hash;\n\n                //  the klevs function\n                var returnParameter = new URLSearchParams(window.location.search);\n                returnParameter.set(\'pg\', p.hash);\n                history.pushState({list: $(\'[js-history-content="articles"]\').html()}, null, location.pathname + \'?\' + returnParameter.toString());\n\n                // prevent browser to scroll\n                $(document).scrollTop(scrollTop);\n            }\n        }\n    };\n\n    $.scrollHash();\n\n\n    //  COPY PHONE\n    $.jsCopyToClipboard(\'[js-copyphone-trigger]\', \'[js-copyphone-target]\', false, \'Copiado para a memória\', \'b-success text-success\');\n\n\n    //\n    //  IS ON SCREEN\n    //\n\n    $.isOnScreen = function ($var, $var1, $toggle) {\n        var timer;\n\n        $(window).on("scroll resize load ready", function () {\n\n            if (timer) {\n                window.clearTimeout(timer);\n            }\n\n            timer = window.setTimeout(function () {\n                $($var).each(function () {\n                    var _this = $(this);\n\n                    if (_this.visible(true)) {\n                        $(_this).addClass($var1);\n                    } else {\n                        if ($toggle === true) {\n                            $(_this).removeClass($var1);\n                        }\n                    }\n                });\n            }, 0);\n        });\n    };\n\n    $.isOnScreen(\'.illu--in\', \'isVisible\', false);\n\n\n    //  ILLU ON HASH\n    \n    var illuOnHash = \'.illu--onhash\';\n\n    $.illuOnHash = function () {\n\n        if (!location.hash) {\n            $(illuOnHash).removeClass(\'isVisible\');\n            \n        } else {\n            var elementTarget = $(document.getElementById(location.hash.substring(1)));\n            console.log(elementTarget);\n\n            if (elementTarget.is(weAreFixed)) {\n                elementTarget.find(illuOnHash).addClass(\'isVisible\');\n            }\n        }\n\n    };\n\n    //  when url has hash, rerun hash function\n    $(window).on(\'hashchange load ready\', function () {\n        $.illuOnHash();\n    });\n\n    $(document).on(\'click\', weRemoveHash, function () {\n        $(illuOnHash).removeClass(\'isVisible\');\n    });\n\n    //\n    //  BUTTON UP\n    //\n\n    var btnUp = \'.btn--up\';\n\n    $(document).on(\'scroll\', function () {\n        var scrollTop = $(document).scrollTop();\n\n        if (scrollTop > $wind.height / 2) {\n            $(btnUp).addClass(\'active\');\n\n        } else {\n            $(btnUp).removeClass(\'active\');\n        }\n    });\n\n    //  scroll\n\n    $(btnUp).click(function (e) {\n        var position = $($(this).attr("href")).offset().top;\n\n        $("body, html").animate({\n            scrollTop: position\n        }, 500);\n    });\n',
#  '/script>\n\n',
#  'script>\n\n    //  DATA-PARALLAX script\n\n    $(function () {\n        ParallaxScroll.init();\n    });\n\n    var ParallaxScroll = {\n\t\t/* PUBLIC VARIABLES */\n        showLogs: false,\n        round: 1000,\n\t\t\n\t\t/* PUBLIC FUNCTIONS */\n        init: function () {\n            this._log("init");\n            if (this._inited) {\n                this._log("Already Inited");\n                this._inited = true;\n                return;\n            }\n            this._requestAnimationFrame = (function () {\n                return window.requestAnimationFrame ||\n                    window.webkitRequestAnimationFrame ||\n                    window.mozRequestAnimationFrame ||\n                    window.oRequestAnimationFrame ||\n                    window.msRequestAnimationFrame ||\n                    function (/* function */ callback, /* DOMElement */ element) {\n                        window.setTimeout(callback, 1000 / 60);\n                    };\n            })();\n            this._onScroll(true);\n        },\n\t\t\n\t\t/* PRIVATE VARIABLES */\n        _inited: false,\n        _properties: [\'x\', \'y\', \'z\', \'rotateX\', \'rotateY\', \'rotateZ\', \'scaleX\', \'scaleY\', \'scaleZ\', \'scale\'],\n        _requestAnimationFrame: null,\n\t\t\n\t\t/* PRIVATE FUNCTIONS */\n        _log: function (message) {\n            if (this.showLogs) console.log("Parallax Scroll / " + message);\n        },\n        _onScroll: function (noSmooth) {\n            var scroll = $(document).scrollTop();\n            var windowHeight = $(window).height();\n            this._log("onScroll " + scroll);\n            $("[data-parallax]").each($.proxy(function (index, el) {\n                var $el = $(el);\n                var properties = [];\n                var applyProperties = false;\n                var style = $el.data("style");\n                if (style == undefined) {\n                    style = $el.attr("style") || "";\n                    $el.data("style", style);\n                }\n                var datas = [$el.data("parallax")];\n                var iData;\n                for (iData = 2; ; iData++) {\n                    if ($el.data("parallax" + iData)) {\n                        datas.push($el.data("parallax-" + iData));\n                    }\n                    else {\n                        break;\n                    }\n                }\n                var datasLength = datas.length;\n                for (iData = 0; iData ',
#  ' datasLength; iData++) {\n                    var data = datas[iData];\n                    var scrollFrom = data["from-scroll"];\n                    if (scrollFrom == undefined) scrollFrom = Math.max(0, $(el).offset().top - windowHeight);\n                    scrollFrom = scrollFrom | 0;\n                    var scrollDistance = data["distance"];\n                    var scrollTo = data["to-scroll"];\n                    if (scrollDistance == undefined && scrollTo == undefined) scrollDistance = windowHeight;\n                    scrollDistance = Math.max(scrollDistance | 0, 1);\n                    var easing = data["easing"];\n                    var easingReturn = data["easing-return"];\n                    if (easing == undefined || !$.easing || !$.easing[easing]) easing = null;\n                    if (easingReturn == undefined || !$.easing || !$.easing[easingReturn]) easingReturn = easing;\n                    if (easing) {\n                        var totalTime = data["duration"];\n                        if (totalTime == undefined) totalTime = scrollDistance;\n                        totalTime = Math.max(totalTime | 0, 1);\n                        var totalTimeReturn = data["duration-return"];\n                        if (totalTimeReturn == undefined) totalTimeReturn = totalTime;\n                        scrollDistance = 1;\n                        var currentTime = $el.data("current-time");\n                        if (currentTime == undefined) currentTime = 0;\n                    }\n                    if (scrollTo == undefined) scrollTo = scrollFrom + scrollDistance;\n                    scrollTo = scrollTo | 0;\n                    var smoothness = data["smoothness"];\n                    if (smoothness == undefined) smoothness = 30;\n                    smoothness = smoothness | 0;\n                    if (noSmooth || smoothness == 0) smoothness = 1;\n                    smoothness = smoothness | 0;\n                    var scrollCurrent = scroll;\n                    scrollCurrent = Math.max(scrollCurrent, scrollFrom);\n                    scrollCurrent = Math.min(scrollCurrent, scrollTo);\n                    if (easing) {\n                        if ($el.data("sens") == undefined) $el.data("sens", "back");\n                        if (scrollCurrent > scrollFrom) {\n                            if ($el.data("sens") == "back") {\n                                currentTime = 1;\n                                $el.data("sens", "go");\n                            }\n                            else {\n                                currentTime++;\n                            }\n                        }\n                        if (scrollCurrent ',
#  ' scrollTo) {\n                            if ($el.data("sens") == "go") {\n                                currentTime = 1;\n                                $el.data("sens", "back");\n                            }\n                            else {\n                                currentTime++;\n                            }\n                        }\n                        if (noSmooth) currentTime = totalTime;\n                        $el.data("current-time", currentTime);\n                    }\n                    this._properties.map($.proxy(function (prop) {\n                        var defaultProp = 0;\n                        var to = data[prop];\n                        if (to == undefined) return;\n                        if (prop == "scale" || prop == "scaleX" || prop == "scaleY" || prop == "scaleZ") {\n                            defaultProp = 1;\n                        }\n                        else {\n                            to = to | 0;\n                        }\n                        var prev = $el.data("_" + prop);\n                        if (prev == undefined) prev = defaultProp;\n                        var next = ((to - defaultProp) * ((scrollCurrent - scrollFrom) / (scrollTo - scrollFrom))) + defaultProp;\n                        var val = prev + (next - prev) / smoothness;\n                        if (easing && currentTime > 0 && currentTime ',
#  '= totalTime) {\n                            var from = defaultProp;\n                            if ($el.data("sens") == "back") {\n                                from = to;\n                                to = -to;\n                                easing = easingReturn;\n                                totalTime = totalTimeReturn;\n                            }\n                            val = $.easing[easing](null, currentTime, from, to, totalTime);\n                        }\n                        val = Math.ceil(val * this.round) / this.round;\n                        if (val == prev && next == to) val = to;\n                        if (!properties[prop]) properties[prop] = 0;\n                        properties[prop] += val;\n                        if (prev != properties[prop]) {\n                            $el.data("_" + prop, properties[prop]);\n                            applyProperties = true;\n                        }\n                    }, this));\n                }\n                if (applyProperties) {\n                    if (properties["z"] != undefined) {\n                        var perspective = data["perspective"];\n                        if (perspective == undefined) perspective = 800;\n                        var $parent = $el.parent();\n                        if (!$parent.data("style")) $parent.data("style", $parent.attr("style") || "");\n                        $parent.attr("style", "perspective:" + perspective + "px; -webkit-perspective:" + perspective + "px; " + $parent.data("style"));\n                    }\n                    if (properties["scaleX"] == undefined) properties["scaleX"] = 1;\n                    if (properties["scaleY"] == undefined) properties["scaleY"] = 1;\n                    if (properties["scaleZ"] == undefined) properties["scaleZ"] = 1;\n                    if (properties["scale"] != undefined) {\n                        properties["scaleX"] *= properties["scale"];\n                        properties["scaleY"] *= properties["scale"];\n                        properties["scaleZ"] *= properties["scale"];\n                    }\n                    var translate3d = "translate3d(" + (properties["x"] ? properties["x"] : 0) + "px, " + (properties["y"] ? properties["y"] : 0) + "px, " + (properties["z"] ? properties["z"] : 0) + "px)";\n                    var rotate3d = "rotateX(" + (properties["rotateX"] ? properties["rotateX"] : 0) + "deg) rotateY(" + (properties["rotateY"] ? properties["rotateY"] : 0) + "deg) rotateZ(" + (properties["rotateZ"] ? properties["rotateZ"] : 0) + "deg)";\n                    var scale3d = "scaleX(" + properties["scaleX"] + ") scaleY(" + properties["scaleY"] + ") scaleZ(" + properties["scaleZ"] + ")";\n                    var cssTransform = translate3d + " " + rotate3d + " " + scale3d + ";";\n                    this._log(cssTransform);\n                    $el.attr("style", "transform:" + cssTransform + " -webkit-transform:" + cssTransform + " " + style);\n                }\n            }, this));\n            if (window.requestAnimationFrame) {\n                window.requestAnimationFrame($.proxy(this._onScroll, this, false));\n            }\n            else {\n                this._requestAnimationFrame($.proxy(this._onScroll, this, false));\n            }\n        }\n    }\n',
#  '/script>\n',
#  '/body>',
#  '/html>\n']

# %% [markdown]
# > Mas nós vamos usar o BeatifulSoup para nos ajudar a acessar as tag´s sem nos preocuparmos em ficar quebrando textos

# %%
html = ConsultaWebB('https://www.camaraindaial.sc.gov.br/pg/proposicoes')
soup = bs4.BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="h-100">
#  <head>
#   <!--GENERAL-->
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <!--PAGE TYPE-->
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <!--TITLE-->
#   <title>
#    Proposições   |  Câmara Municipal de Indaial
#   </title>
#   <meta content="Proposições" property="twitter:title"/>
#   <meta content="Proposições" property="og:title"/>
#   <!--SUBTITLE-->
#   <meta content="" property="twitter:description"/>
#   <meta content="" property="og:description"/>
#   <!--DESCRIPTION-->
#   <meta content="Conteúdo estático com links para o Legislador." property="description"/>
#   <!--IMGS-->
#   <meta content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg" property="twitter:image"/>
#   <meta content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg" property="twitter:image:alt"/>
#   <meta content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg" property="image"/>
#   <meta content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/metatag.jpg" property="og:image"/>
#   <!--YOUTUBE VIDEO-->
#   <!--URL-->
#   <link href="https://www.camaraindaial.sc.gov.br/pg/proposicoes" rel="canonical"/>
#   <meta content="https://www.camaraindaial.sc.gov.br/pg/proposicoes" property="og:url"/>
#   <meta content="https://www.camaraindaial.sc.gov.br/pg/proposicoes" property="twitter:url"/>
#   <!--OFFICE-->
#   <meta content="Câmara Municipal de Indaial" property="copyright"/>
#   <meta content="Câmara Municipal de Indaial" property="og:site_name"/>
#   <meta content="Rua Prefeito Frederico Hardt, 148" property="og:street-address"/>
#   <meta content="Indaial" property="og:locality"/>
#   <meta content="Santa Catarina" property="og:region"/>
#   <meta content="89080-018" property="og:postal-code"/>
#   <meta content="Brazil" property="og:country-name"/>
#   <meta content="secretaria@camaraindaial.sc.gov.br " property="og:email"/>
#   <meta content="+55(47) 3380-6900" property="og:phonenumber"/>
#   <meta content="secretaria@camaraindaial.sc.gov.br " property="reply-to"/>
#   <!--CUSTOM-->
#   <meta content="" name="google-analytics">
#    <meta content="" name="disqus">
#     <!-- CSS -->
#     <link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-application.min.css?v=1.1" media="screen" rel="stylesheet" type="text/css">
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/css/dist-utilities.min.css?v=1.1" media="screen" rel="stylesheet" type="text/css"/>
#      <!-- Favicons -->
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#      <link href="https://www.camaraindaial.sc.gov.br/view/dist/imgs/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#      <meta content="https://www.camaraindaial.sc.gov.br/view/dist/imgs/ms-icon-144x144.png" name="msapplication-TileImage"/>
#      <!--Project Color for Mobile Browsers-->
#      <meta content="#000" name="msapplication-TileColor"/>
#      <meta content="#000" name="theme-color"/>
#      <!--HEAD CODES-->
#      <!-- Google Tag Manager -->
#      <script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WBCNNX7');
#      </script>
#      <!-- End Google Tag Manager -->
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- body inicio -->
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WBCNNX7" style="display:none; visibility:hidden">
#    </iframe>
#   </noscript>
#   <header>
#    <div class="container">
#     <!--first line-->
#     <div class="row align-center">
#      <div class="col-6 col-4-md flex-center">
#       <!--LOGOTYPE-->
#       <a href="/home">
#        <picture>
#         <!--<source srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/android-icon-48x48.png" media="(max-width:640px)"/>-->
#         <img alt="Câmara Municipal de Indaial" class="w-auto maxh-base-5 maxh-base-7-sm maxh-base-10-md" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/logotype.png"/>
#        </picture>
#       </a>
#      </div>
#      <div class="col-6 px-0 px-1-sm hides-md text-right">
#       <button aria-label="search" class="btn btn--icon hides" href="#busca" js-global-focus="#busca .search-bar__input" role="button" type="button">
#        <i class="icon" data-icon="search">
#        </i>
#       </button>
#       <button aria-label="menu" class="btn btn--icon b-3 b-dark text-dark mx-1" href="#menu" role="button" type="button">
#        <i class="icon font-base" data-icon="menu">
#        </i>
#       </button>
#      </div>
#      <div class="col-8-md p-0 px-1-sm p-0-md nmb-1-md">
#       <i class="divider m-1 hides-md">
#       </i>
#       <ul class="nav align-center justify-center-sm justify-end-md fw-bold font-small font-base-md font-2 flex-nowrap-md py-1-md pr-2-md">
#        <li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">
#         <a aria-label="Acesso à informação" class="nav__link py-1 pl-1 pr-0 flex-center b-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa brand-text-primary-hfa" href="/atendimento/acesso-a-informacao">
#          <picture class="">
#           <source media="(max-width:412px)" srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink2.png"/>
#           <img alt="" aria-label="" class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink2.png"/>
#          </picture>
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           Acesso à informação
#          </span>
#         </a>
#        </li>
#        <li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">
#         <a aria-label="Licitações e Contratos" class="nav__link py-1 pl-1 pr-0 flex-center b-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa brand-text-primary-hfa" href="/licitacoes-e-contratos">
#          <picture class="">
#           <source media="(max-width:412px)" srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink1.png"/>
#           <img alt="" aria-label="" class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink1.png"/>
#          </picture>
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           Licitações e Contratos
#          </span>
#         </a>
#        </li>
#        <li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">
#         <a aria-label="Portal da Transparência" class="nav__link py-1 pl-1 pr-0 flex-center b-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa brand-text-primary-hfa" href="https://portalcamaraindaial.atende.net/#!/" rel="noreferrer" target="_blank">
#          <picture class="">
#           <source media="(max-width:412px)" srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink3.png"/>
#           <img alt="" aria-label="" class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink3.png"/>
#          </picture>
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           Portal da Transparência
#          </span>
#         </a>
#        </li>
#        <li class="nav__item flex-center w-50 p-0 m-0 w-25-sm">
#         <a aria-label="Ouvidoria &amp;&lt;br/&gt;Carta de Serviços" class="nav__link py-1 pl-1 pr-0 flex-center b-0 brand-b-primary-h brand-text-secondary-hf brand-text-primary-a bg-transparent-hfa brand-text-primary-hfa" href="/atendimento">
#          <picture class="">
#           <source media="(max-width:412px)" srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink4.png"/>
#           <img alt="" aria-label="" class="swiper-lazy w-auto maxh-base-3 maxh-base-5-md mr-1 mr-2-sm flex-noshrink" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/headerLink4.png"/>
#          </picture>
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           Ouvidoria &amp;
#           <br/>
#           Carta de Serviços
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="float-container hides flex-md" style="margin-bottom: -1px;">
#     <div class="container mr-0 py-0">
#      <div class="row align-end">
#       <div class="col-12 p-0 px-1-sm">
#        <i class="divider bb-3 my-0 mx-1 b-dark">
#        </i>
#        <ul class="nav font-small font-base-md font-2 py-1-sm relative fw-regular justify-between">
#         <li class="nav__item inline-block">
#          <a aria-label="Institucional" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/institucional">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Institucional
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Vereadores" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/vereadores">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Vereadores
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Imprensa" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/imprensa">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Imprensa
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Agenda" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/agenda">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Agenda
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Pautas" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/pautas">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Pautas
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Legislação" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/pg/legislacao">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Legislação
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Proposições  " class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/pg/proposicoes">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Proposições
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Parlamento Jovem" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/parlamento-jovem">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Parlamento Jovem
#            </span>
#           </span>
#          </a>
#         </li>
#         <li class="nav__item inline-block">
#          <a aria-label="Fale conosco" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa mr-h" href="/atendimento">
#           <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#            <span class="dropdown__clone">
#             Fale conosco
#            </span>
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <form action="/pg/proposicoes" class="search-bar search-bar--fullscreen z-index-3" id="busca" method="get">
#    <div class="search-bar__vessel">
#     <div class="search-bar__bar py-1 p-3-sm p-6-md">
#      <i class="icon w-base-5 text-dark" data-icon="search">
#      </i>
#      <div class="search-bar__content font-small font-base-md">
#       <input aria-label="Busca" class="search-bar__input h-base-5 h-base-6-sm fw-bold font-largex" name="q" type="search" value=""/>
#       <span class="search-bar__label text-italic mt-h-sm font-large-sm">
#        O que você está procurando?
#       </span>
#      </div>
#      <button aria-label="close" class="btn btn--icon" role="button" type="reset">
#       <i class="icon icon--3" data-icon="close">
#       </i>
#      </button>
#     </div>
#    </div>
#    <button aria-label="Fechar" class="scrimmer" type="button">
#    </button>
#   </form>
#   <!--drawer nav-->
#   <div class="drawer" id="menu">
#    <div class="drawer__vessel maxw-unit-6">
#     <div class="drawer__content py-0">
#      <div class="flex">
#       <button aria-label="long-arrow-left" class="btn btn--icon text-icon mx-1 my-1" js-dismiss=".drawer" js-dismiss-hash="" role="button" type="button">
#        <i class="icon icon--3" data-icon="long-arrow-left">
#        </i>
#       </button>
#      </div>
#      <div class="flex flex-column fw-bold font-base pb-6 divider-group-last font-2">
#       <div class="font-1 mb-2 flex flex-column align-start p-2" style="background-color: #f5f5f5;">
#        <a aria-label="(47) 3380-6900" class="btn btn--raised btn--primary btn--inverse w-100 text-initial font-base py-1 px-2 b-1tooltiper" data-action="" href="tel:4733806900" js-copyphone-target="(47) 3380-6900" js-copyphone-trigger="this" nojs="" title="Das 8h30 às 20h30">
#         <i class="icon font-large" data-icon="phone">
#         </i>
#         <span class="btn__label">
#          (47) 3380-6900
#         </span>
#        </a>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="institucional1" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Institucional" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/institucional">
#          <span>
#           Institucional
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#institucional1">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="História" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/institucional/historia" style="white-space: normal">
#           História
#          </a>
#          <a aria-label="Escola do Legislativo" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/institucional/escola-do-legislativo" style="white-space: normal">
#           Escola do Legislativo
#          </a>
#          <a aria-label="Regimento Interno" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/institucional/regimento-interno" style="white-space: normal">
#           Regimento Interno
#          </a>
#          <a aria-label="Lei Orgânica" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/institucional/lei-organica" style="white-space: normal">
#           Lei Orgânica
#          </a>
#          <a aria-label="Perguntas Frequentes" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/institucional/perguntas-frequentes" style="white-space: normal">
#           Perguntas Frequentes
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="vereadores2" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Vereadores" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/vereadores">
#          <span>
#           Vereadores
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#vereadores2">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="Vereadores" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/vereadores/vereadores" style="white-space: normal">
#           Vereadores
#          </a>
#          <a aria-label="Mesa Diretora" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/vereadores/mesa-diretora" style="white-space: normal">
#           Mesa Diretora
#          </a>
#          <a aria-label="Comissões Permanentes" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/vereadores/comissoes-permanentes" style="white-space: normal">
#           Comissões Permanentes
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="imprensa3" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Imprensa" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/imprensa">
#          <span>
#           Imprensa
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#imprensa3">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="Notícias" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/imprensa/noticias" style="white-space: normal">
#           Notícias
#          </a>
#          <a aria-label="Resumo das sessões" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/imprensa/sessoes" style="white-space: normal">
#           Resumo das sessões
#          </a>
#          <a aria-label="Atas das Sessões" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/imprensa/atas-das-sessoes" style="white-space: normal">
#           Atas das Sessões
#          </a>
#          <a aria-label="Galeria de imagens" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/imprensa/galeria-de-imagens" style="white-space: normal">
#           Galeria de imagens
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="divider-after">
#        <a aria-label="Agenda" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/agenda">
#         <span>
#          Agenda
#         </span>
#        </a>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="pautas5" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Pautas" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/pautas">
#          <span>
#           Pautas
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#pautas5">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="Sessão Ordinária" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="https://www.camaraindaial.sc.gov.br/pautas/sessao-ordinaria" style="white-space: normal">
#           Sessão Ordinária
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="divider-after">
#        <a aria-label="Legislação" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/pg/legislacao">
#         <span>
#          Legislação
#         </span>
#        </a>
#       </div>
#       <div class="divider-after">
#        <a aria-label="Proposições  " class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple active" href="/pg/proposicoes">
#         <span>
#          Proposições
#         </span>
#        </a>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="parlamento-jovem8" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Parlamento Jovem" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/parlamento-jovem">
#          <span>
#           Parlamento Jovem
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#parlamento-jovem8">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="Notícias" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/parlamento-jovem/noticias-jovem" style="white-space: normal">
#           Notícias
#          </a>
#          <a aria-label="Galeria de imagens" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/parlamento-jovem/galeria-de-imagens-jovem" style="white-space: normal">
#           Galeria de imagens
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="divider-after collapse__item">
#        <input class="collapse__input" id="atendimento9" type="checkbox"/>
#        <div class="relative">
#         <a aria-label="Fale conosco" class="flex-center ripple minh-base-5 fw-bold py-2 pl-3 pr-1 brand-bg-secondary-lighter-a ripple" href="/atendimento">
#          <span>
#           Fale conosco
#          </span>
#         </a>
#         <button class="btn btn--icon flex-noshrink absolute-tr" js-global-toggle-check="#atendimento9">
#          <i class="icon collapse__icon text-dark" data-icon="chevron-down">
#          </i>
#         </button>
#        </div>
#        <div class="collapse__vessel">
#         <div class="collapse__content pb-2">
#          <a aria-label="Ouvidoria" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/atendimento/ouvidoria" style="white-space: normal">
#           Ouvidoria
#          </a>
#          <a aria-label="Carta de Serviços" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/atendimento/carta-de-servicos" style="white-space: normal">
#           Carta de Serviços
#          </a>
#          <a aria-label="Acesso à informação" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/atendimento/acesso-a-informacao" style="white-space: normal">
#           Acesso à informação
#          </a>
#          <a aria-label="Fale Conosco" class="flex-center ripple fw-bold py-2 pl-3 brand-text-secondary-a pl-6 ripple" href="/atendimento/fale-conosco" style="white-space: normal">
#           Fale Conosco
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="py-2 px-h">
#        <a aria-label="instagram" class="btn btn--icon btn--primary w-base-6 h-base-6" href="https://www.instagram.com/camaraindaial/" rel="noreferrer" target="_blank">
#         <i class="icon icon--3" data-icon="instagram">
#         </i>
#        </a>
#        <a aria-label="facebook-box" class="btn btn--icon btn--primary w-base-6 h-base-6" href="https://www.facebook.com/camaraindaial/" rel="noreferrer" target="_blank">
#         <i class="icon icon--3" data-icon="facebook-box">
#         </i>
#        </a>
#        <a aria-label="youtube-play" class="btn btn--icon btn--primary w-base-6 h-base-6" href="#/" rel="noreferrer" target="_blank">
#         <i class="icon icon--3" data-icon="youtube-play">
#         </i>
#        </a>
#        <a aria-label="linkedin" class="btn btn--icon btn--primary w-base-6 h-base-6" href="#/" rel="noreferrer" target="_blank">
#         <i class="icon icon--3" data-icon="linkedin">
#         </i>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <button aria-label="Fechar" class="scrimmer" type="button">
#    </button>
#   </div>
#   <!--CONTENT-->
#   <div class="relative bt-1">
#    <div class="absolute h-100 w-100 overflow-hidden" style="top:0; left:0;">
#     <div class="absolute" style="top:50%; left:0; transform: translateY(-50%);">
#      <picture class="">
#      </picture>
#     </div>
#    </div>
#    <div class="container">
#     <div class="row">
#      <div class="col-12 flex-column py-4-sm py-8-md relative z-index-1 text-center">
#       <div class="nmt-2-md nmx-2">
#        <nav class="breadcrumb text-uppercase fw-bold font-2 flex-center-center">
#         <a class="breadcrumb__item" href="/home">
#          Home
#         </a>
#         <a class="breadcrumb__item active hides" href="/pg/proposicoes">
#          Proposições
#         </a>
#        </nav>
#       </div>
#       <div class="nmt-2 mt-0-md">
#        <div class="">
#         <div class="font-2 fw-bold h6 h5-sm h2-md lh-small nletter-1 text-dark">
#          Proposições
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <section class="bt-1">
#    <div class="container img-load px-2-md py-6-md">
#     <div class="row justify-center">
#      <div class="col-9-sm col-6-md post">
#       <p>
#        <strong>
#         <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProposicaoConsulta&amp;ID=3&amp;tpProposicao=1&amp;" target="_blank">
#          <span style="color: rgb(192, 80, 77);">
#           <span style="font-size: 18px;">
#            Indicações
#           </span>
#          </span>
#          <span style="font-size: 14px; color: rgb(192, 80, 77);">
#           (pesquise aqui)
#          </span>
#         </a>
#        </strong>
#        <br/>
#       </p>
#       <p>
#        Proposições escritas, por meio das quais o vereador sugere medidas de interesse público aos poderes competentes.
#       </p>
#       <p>
#        <br/>
#       </p>
#       <p>
#        <strong>
#         <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProposicaoConsulta&amp;ID=3&amp;tpProposicao=3&amp;" target="_blank">
#          <span style="font-size: 18px;">
#          </span>
#         </a>
#         <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProposicaoConsulta&amp;ID=3&amp;tpProposicao=3&amp;" target="_blank">
#          <span style="color: rgb(192, 80, 77);">
#           <span style="font-size: 18px;">
#            Moções
#           </span>
#           <span style="font-size: 14px;">
#            (pesquise aqui)
#           </span>
#          </span>
#         </a>
#         <span style="font-size: 14px;">
#         </span>
#         <span style="font-size: 14px;">
#         </span>
#        </strong>
#       </p>
#       <p>
#        Proposições escritas, por meio das quais o parlamentar se manifesta sobre determinado assunto, aplaudindo ou repudiando ações, por exemplo.
#       </p>
#       <p>
#        <br/>
#       </p>
#       <p>
#        <strong>
#         <span style="color: rgb(192, 80, 77);">
#          <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProposicaoConsulta&amp;ID=3&amp;tpProposicao=2&amp;" target="_blank">
#           <span style="color: rgb(192, 80, 77);">
#            <span style="font-size: 18px;">
#            </span>
#           </span>
#          </a>
#          <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProposicaoConsulta&amp;ID=3&amp;tpProposicao=2&amp;">
#           <span style="color: rgb(192, 80, 77);">
#            <span style="font-size: 18px;">
#             Requerimentos
#            </span>
#           </span>
#           <span style="font-size: 14px; color: rgb(192, 80, 77);">
#            (pesquise aqui)
#           </span>
#          </a>
#         </span>
#         <span style="font-size: 14px;">
#         </span>
#        </strong>
#       </p>
#       <p>
#        Proposições verbais ou escritas, apresentadas por vereadores ou comissões, feitas ao presidente da Câmara ou por seu intermédio, sobre assunto do expediente, da ordem do dia, ou de interesse do vereador.
#       </p>
#       <p>
#        <span style="color: rgb(192, 80, 77);">
#         <br/>
#        </span>
#       </p>
#       <p>
#        <strong>
#         <a href="http://www.legislador.com.br/LegisladorWEB.ASP?WCI=ProjetoParametro&amp;ID=3" target="_blank">
#          <span style="color: rgb(192, 80, 77);">
#           Projetos (pesquise aqui)
#          </span>
#         </a>
#        </strong>
#       </p>
#       <p>
#        Proposições escritas. Texto articulado contendo normas que virão a ter caráter jurídico por meio do processo legislativo.
#       </p>
#       <p>
#        <br/>
#       </p>
#      </div>
#     </div>
#    </div>
#   </section>
#   <!--call footer-->
#   <footer class="py-2 py-4-sm py-6-md">
#    <div class="container">
#     <div class="row justify-center">
#      <div class="col-12-md">
#       <div class="nav align-center justify-center font-2 fw-bold font-smallxx text-uppercase">
#        <li class="nav__item inline-block">
#         <a aria-label="Institucional" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/institucional">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Institucional
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Vereadores" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/vereadores">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Vereadores
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Imprensa" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/imprensa">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Imprensa
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Agenda" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/agenda">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Agenda
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Pautas" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/pautas">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Pautas
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Legislação" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/pg/legislacao">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Legislação
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Proposições  " class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/pg/proposicoes">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Proposições
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Parlamento Jovem" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/parlamento-jovem">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Parlamento Jovem
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Fale conosco" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/atendimento">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Fale conosco
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Licitações e Contratos" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/licitacoes-e-contratos">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Licitações e Contratos
#           </span>
#          </span>
#         </a>
#        </li>
#        <li class="nav__item inline-block">
#         <a aria-label="Concurso público" class="nav__link text-nowrap flex-noshrink py-1 px-0 flex-center px-1 b-0 brand-b-primary-h brand-text-secondary-hf brand-text-secondary-a bg-transparent-hfa dropdown__item brand-text-primary-hfa px-1" href="/concurso-publico">
#          <span class="bb-2 b-transparent brand-b-primary-lighter-a">
#           <span class="dropdown__clone">
#            Concurso público
#           </span>
#          </span>
#         </a>
#        </li>
#       </div>
#       <i class="divider p-0 my-2">
#       </i>
#       <div class="flex-center-center flex-wrap py-h">
#        <a aria-label="(47) 3380-6900" class="btn btn--primary fw-regular text-initial font-base-md tooltiper" data-action="" href="tel:4733806900" js-copyphone-target="(47) 3380-6900" js-copyphone-trigger="this" nojs="" title="Das 8h30 às 20h30">
#         <i class="icon font-large" data-icon="phone">
#         </i>
#         <span class="btn__label">
#          (47) 3380-6900
#         </span>
#        </a>
#        <a aria-label="secretaria@camaraindaial.sc.gov.br " class="btn btn--primary fw-regular text-initial font-base-md" data-action="" href="1" js-copyphone-target="secretaria@camaraindaial.sc.gov.br " js-copyphone-trigger="" nojs="" title="">
#         <i class="icon font-large" data-icon="email">
#         </i>
#         <span class="btn__label">
#          secretaria@camaraindaial.sc.gov.br
#         </span>
#        </a>
#        <a aria-label="Instagram" class="btn btn--primary fw-regular text-initial font-base-md" data-action="" href="https://www.instagram.com/camaraindaial/" js-copyphone-target="Instagram" js-copyphone-trigger="" nojs="" rel="noreferrer" target="_blank" title="">
#         <i class="icon font-large" data-icon="instagram">
#         </i>
#         <span class="btn__label">
#          Instagram
#         </span>
#        </a>
#        <a aria-label="Facebook" class="btn btn--primary fw-regular text-initial font-base-md" data-action="" href="https://www.facebook.com/camaraindaial/" js-copyphone-target="Facebook" js-copyphone-trigger="" nojs="" rel="noreferrer" target="_blank" title="">
#         <i class="icon font-large" data-icon="facebook-box">
#         </i>
#         <span class="btn__label">
#          Facebook
#         </span>
#        </a>
#       </div>
#       <div class="flex-center-center text-secondary text-initial text-left text-center-md py-1 pt-2-sm pt-4-md lh-large-md font-smallxx font-smallx-sm">
#        <div class="p-1">
#         © 2021 Câmara Municipal de Indaial – Rua Prefeito Frederico Hardt, 148, Centro, Indaial, Santa Catarina,
#         <span class="text-nowrap inline">
#          89080-018
#         </span>
#        </div>
#        <i class="divider-y minh-base-2 hides shows-sm">
#        </i>
#        <div class="p-1 text-right flex-noshrink fw-medium">
#         <a class="bb-1 b-error" href="http://www.mlbc.com.br" target="_blank">
#          <span class="text-secondary">
#           MLBC
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="row justify-center">
#      <div class="col-2-md text-center">
#       <!--LOGOTYPE-->
#       <a href="/home">
#        <picture>
#         <source media="(max-width:640px)" srcset="https://www.camaraindaial.sc.gov.br/view/dist/imgs/android-icon-48x48.png"/>
#         <img alt="Câmara Municipal de Indaial" class="w-auto maxh-base-5 maxh-base-6-sm" src="https://www.camaraindaial.sc.gov.br/view/dist/imgs/logotype.png"/>
#        </picture>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!--body final-->
#   <!--call base scripts-->
#   <!--core script-->
#   <script src="https://www.camaraindaial.sc.gov.br/view/dist/js/application.min.js">
#   </script>
#   <script>
#    //
#     //  OVERFLOW SCROLL X
#     //  Function to make scroll jumping to actived item
#     //
#     $.overflowScrollX = function ($var, $var1, $var2) {
#         var $container = $($var);
#         var $target = $($var1);
#         var gutter = $var2;
#         if ($target.length && $container.length) {
#             $container.animate({
#                 scrollLeft: $target.offset().left - $container.offset().left + $container.scrollLeft() + (gutter),
#             }, 600);
#         }
#     }
#     $.overflowScrollX('.nav--x', '.active', null);
#     $(document).on('click', '.nav--x a', function (e) {
#         $.overflowScrollX('.nav--x', 'nav--x .active', null);
#     });
#     //
#     //  OVERFLOW SCROLL Y
#     //  Function to make scroll jumping to actived item
#     //
#     $.overflowScrollY = function ($var, $var1, $var2=0) {
#         var $container = $($var);
#         var $target = $($var1);
#         var gutter = $var2;
#         if ($target.length) {
#             $container.animate({
#                 scrollTop: $target.offset().top + (gutter),
#                 scrollLeft: 0
#             }, 600);
#         }
#     }
#     $.overflowScrollY('.search-bar__results', '.search-bar__results *:first-child');
#     $(document).on('click', '#mainSearchbar .search-bar__bar', function () {
#         if ($wind.width >= 640) {
#             gutter = -16;
#         } else {
#             gutter = -12;
#         }
#         $.overflowScrollY('html, body', '#mainSearchbar', gutter);
#     });
#
#
#     //
#     //  NEWSBAR CAROUSEL
#     //
#     $('#newsbar').owlCarousel({
#         loop: true,
#         dots: false,
#         mouseDrag: false,
#         autoplay: true,
#         autoplayTimeout: 4000,
#         autoplayHoverPause: true,
#         margin: 0,
#         navText: ['<i class="icon" data-icon="chevron-left"></i>', '<i class="icon" data-icon="chevron-right"></i>'],
#         navSpeed: 150,
#         items: 1,
#         responsive: {
#             640: {
#                 nav: true,
#             }
#         }
#     });
#
#     //
#     //  BUBBLY BUTTON
#     //
#
#     $(document).on('click', '.btn--bubbly', function (e) {
#
#         //e.preventDefault;
#         //reset animation
#         $(this).removeClass('animate pulse');
#
#         $(this).addClass('animate pulse');
#         setTimeout(function () {
#             $('.btn--bubbly').removeClass('animate pulse');
#         }, 750);
#     });
#
#     //
#     //  VALIDATE
#     //
#
#     //  DEFAULTS
#
#     jQuery.validator.setDefaults({
#         onkeyup: false,
#
#         highlight: function (element, errorClass, validClass) {
#             if ($(element).is(':checkbox') || $(element).is(':radio') || $(element).is(':file')) {
#
#                 if ($(element).parents('.control-group').length) {
#                     $(element).parents('.control-group').find('.alert').addClass(errorClass + ' active').removeClass(validClass);
#
#                 } else {
#                     $(element).parents('.control').addClass('text-error').removeClass(validClass);
#                 }
#             } else {
#                 $(element).parents('.textfield').addClass(errorClass).removeClass(validClass);
#             }
#             //  unload submit button
#             $(element).parents('form').find('[type="submit"]').removeClass('active');
#         },
#
#         unhighlight: function (element, errorClass, validClass) {
#             if ($(element).is(':checkbox') || $(element).is(':radio') || $(element).is(':file')) {
#
#                 if ($(element).parents('.control-group').length) {
#                     $(element).parents('.control-group').find('.alert').removeClass(errorClass + ' active');
#
#                 } else {
#                     $(element).parents('.control').removeClass('text-error');
#                 }
#             } else {
#                 $(element).parents('.textfield').removeClass(errorClass);
#             }
#             //  unload submit button
#             $(element).parents('form').find('[type="submit"]').removeClass('active');
#         },
#
#         errorPlacement: function (error, element) {
#             if ($(element).is(':checkbox') || $(element).is(':radio') || $(element).is(':file')) {
#
#                 if ($(element).is(':checkbox') || $(element).is(':radio')) {
#                     error.appendTo(element.parents('.control-group').find('.alert__label'));
#
#                 } else if ($(element).get(0).files.length === 0) {
#                     error.appendTo(element.parents('.file-group').find('.alert__label'));
#                 }
#
#             } else {
#                 error.appendTo(element.parents('.textfield__content')).addClass('textfield__hint');
#             }
#         }
#     });
#
#     //  VOUCHER
#
#     $("#validateVoucher").validate({
#         rules: {
#             txt: {
#                 required: true,
#             },
#         },
#
#         messages: {
#             txt: {
#                 required: "Digite um código",
#             }
#         }
#     });
#
#     //  NEWSLETTER
#
#     $("#validateNewsletter").submit(function (e) {
#         e.preventDefault();
#         form = $(this).serialize();
#         element = $(this).attr('id');
#
#         $.ajax({
#             url: '/verificacoes',
#             type: 'POST',
#             dataType: 'html',
#             data: form,
#         })
#             .done(function (data) {
#                 mensagem(data, element);
#             })
#             .fail(function () {
#                 console.log("error");
#             })
#     }).validate({
#         onkeyup: false,
#
#         rules: {
#
#             email: {
#                 required: true,
#                 email: true,
#             },
#         },
#     });
#
#     function mensagem(retorno, e) {
#         dados = "operacao=mensagem&retorno=" + retorno;
#         $.ajax({
#             url: "/verificacoes",
#             method: "POST",
#             dataType: 'html',
#             data: dados,
#         })
#             .done(function (data) {
#                 console.log($('#' + e));
#                 $('#' + e).html(data);
#             })
#             .fail(function () {
#                 console.log("error");
#             })
#             .always(function () {
#                 console.log("complete");
#             });
#
#     }
#   </script>
#   <script>
#    //  TOAST
#
#     function falhaXHR(jqXHR, textStatus) {
#         if (jqXHR.status === 0) {
#             $('.toast').find('.toast__label').html('Sem conexão com a internet!');
#             $('.toast').find('.toast__item').addClass('active');
#         }
#         else if (jqXHR.status == 404) {
#             $('.toast').find('.toast__label').html('Página indisponível!');
#             $('.toast').find('.toast__item').addClass('active');
#         }
#         else if (jqXHR.status == 500) {
#             $('.toast').find('.toast__label').html('Erro interno no servidor!');
#             $('.toast').find('.toast__item').addClass('active');
#         }
#     }
#
#     //
#     //  FORMS
#     //
#
#     $(document).on('click', 'button[js-submit]', function (event) {
#         event.preventDefault();
#         var form = $(this).parents('form');
#         var submit = $(this);
#         var data = form.serialize();
#
#         data = data + '&step=' + $(this).attr('ajax-step');
#
#         send({form: form, data: data, submit: submit});
#     });
#
#     $(document).on('submit', 'form[ajax-send="default"]', function (event) {
#         event.preventDefault();
#
#         var form = $(this);
#
#         $(form).find('[type="submit"]').addClass('active');
#
#         $(form).find('.textfield').removeClass('error');
#         $(form).find('.textfield__content .textfield__hint').remove();
#
# ...
#                         cache: false,
#                         data: data,
#                     })
#                         .done(function (data) {
#                             ajaxActions({form: form, data: data});
#                         })
#                         .fail(function (jqXHR, textStatus) {
#                             falhaXHR(jqXHR, textStatus);
#                         })
#                         .always(function () {
#                             $(form).find('button[type="submit"]').removeClass('active');
#                         });
#
#                 },
#                 error: function (response) {
#                 },
#                 complete: function (response) {
#                 }
#             });
#         }
#     });
#
#     $(document).on('submit', 'form[ajax-send="pagination"]', function (event) {
#         event.preventDefault();
#
#         var form = $(this);
#
#         $(form).find('[type="submit"]').addClass('active');
#
#
#         var pg = $(form).find('[name="pg"]').val();
#         var type = $(form).find('[name="type"]').val();
#
#         var new_pg = pg;
#
#         if (type == 'next') {
#             new_pg++;
#         } else {
#             new_pg--;
#         }
#
#         $(form).find('input[name="pg"]').val(new_pg);
#
#         var data = $(form).serialize();
#
#         $.ajax({
#             url: '/ajax',
#             type: 'POST',
#             dataType: 'json',
#             cache: false,
#             data: data,
#
#         }).done(function (data) {
#             ajaxActions({form: form, data: data});
#             //  rerun hash function
#             $.scrollHash();
#
#         }).fail(function (jqXHR, textStatus) {
#             falhaXHR(jqXHR, textStatus);
#
#         }).always(function () {
#             $(form).find('button[type="submit"]').removeClass('active');
#         });
#
#     });
#
#     //
#     //  UPDATED HASH ON SCROLL
#     //
#
#     $.scrollHash = function () {
#
#         // Find all  top,bottom and Hash of each sections,
#         // Do this only if the section height remain the same always
#         // Move this into the step() if your section height does change.
#         // e.g. browser resize
#
#         var section = $.map($("section"), function (e) {
#             var $e = $(e);
#             var pos = $e.position();
#             return {
#                 top: pos.top,
#                 bottom: pos.top + $e.height(),
#                 hash: $e.attr('id')
#             };
#         });
#
#         //  Checking scroll
#         var top = null;
#         var changed = false;
#         var currentHash = null;
#
#         $(window).bind('scroll mousewheel DOMMouseScroll', function () {
#             var newTop = $(document).scrollTop();
#
#             changed = newTop != top;
#             if (changed) {
#                 top = newTop;
#             }
#             step();
#         });
#
#         // You wouldn't want to keep checking the scroll state as
#         // it affects the browser performance when it's accessing
#         // DOM and reduce your FPS (Frame per Seconds) for scrolling
#         //
#
#         function step() {
#             if (!changed) {
#                 // Top did not change
#                 return setTimeout(step, 500);
#             }
#             var count = section.length;
#             var p;
#
#             while (p = section[--count]) {
#
#
#                 if (p.top >= top || p.bottom <= top) {
#                     continue;
#                 }
#                 if (currentHash == p.hash) {
#                     break;
#                 }
#                 var scrollTop = $(document).scrollTop();
#
#                 //  update current hash
#                 currentHash = p.hash;
#
#                 //  the klevs function
#                 var returnParameter = new URLSearchParams(window.location.search);
#                 returnParameter.set('pg', p.hash);
#                 history.pushState({list: $('[js-history-content="articles"]').html()}, null, location.pathname + '?' + returnParameter.toString());
#
#                 // prevent browser to scroll
#                 $(document).scrollTop(scrollTop);
#             }
#         }
#     };
#
#     $.scrollHash();
#
#
#     //  COPY PHONE
#     $.jsCopyToClipboard('[js-copyphone-trigger]', '[js-copyphone-target]', false, 'Copiado para a memória', 'b-success text-success');
#
#
#     //
#     //  IS ON SCREEN
#     //
#
#     $.isOnScreen = function ($var, $var1, $toggle) {
#         var timer;
#
#         $(window).on("scroll resize load ready", function () {
#
#             if (timer) {
#                 window.clearTimeout(timer);
#             }
#
#             timer = window.setTimeout(function () {
#                 $($var).each(function () {
#                     var _this = $(this);
#
#                     if (_this.visible(true)) {
#                         $(_this).addClass($var1);
#                     } else {
#                         if ($toggle === true) {
#                             $(_this).removeClass($var1);
#                         }
#                     }
#                 });
#             }, 0);
#         });
#     };
#
#     $.isOnScreen('.illu--in', 'isVisible', false);
#
#
#     //  ILLU ON HASH
#
#     var illuOnHash = '.illu--onhash';
#
#     $.illuOnHash = function () {
#
#         if (!location.hash) {
#             $(illuOnHash).removeClass('isVisible');
#
#         } else {
#             var elementTarget = $(document.getElementById(location.hash.substring(1)));
#             console.log(elementTarget);
#
#             if (elementTarget.is(weAreFixed)) {
#                 elementTarget.find(illuOnHash).addClass('isVisible');
#             }
#         }
#
#     };
#
#     //  when url has hash, rerun hash function
#     $(window).on('hashchange load ready', function () {
#         $.illuOnHash();
#     });
#
#     $(document).on('click', weRemoveHash, function () {
#         $(illuOnHash).removeClass('isVisible');
#     });
#
#     //
#     //  BUTTON UP
#     //
#
#     var btnUp = '.btn--up';
#
#     $(document).on('scroll', function () {
#         var scrollTop = $(document).scrollTop();
#
#         if (scrollTop > $wind.height / 2) {
#             $(btnUp).addClass('active');
#
#         } else {
#             $(btnUp).removeClass('active');
#         }
#     });
#
#     //  scroll
#
#     $(btnUp).click(function (e) {
#         var position = $($(this).attr("href")).offset().top;
#
#         $("body, html").animate({
#             scrollTop: position
#         }, 500);
#     });
#   </script>
#   <script>
#    //  DATA-PARALLAX script
#
#     $(function () {
#         ParallaxScroll.init();
#     });
#
#     var ParallaxScroll = {
# 		/* PUBLIC VARIABLES */
#         showLogs: false,
#         round: 1000,
#
# 		/* PUBLIC FUNCTIONS */
#         init: function () {
#             this._log("init");
#             if (this._inited) {
#                 this._log("Already Inited");
#                 this._inited = true;
#                 return;
#             }
#             this._requestAnimationFrame = (function () {
#                 return window.requestAnimationFrame ||
#                     window.webkitRequestAnimationFrame ||
#                     window.mozRequestAnimationFrame ||
#                     window.oRequestAnimationFrame ||
#                     window.msRequestAnimationFrame ||
#                     function (/* function */ callback, /* DOMElement */ element) {
#                         window.setTimeout(callback, 1000 / 60);
#                     };
#             })();
#             this._onScroll(true);
#         },
#
# 		/* PRIVATE VARIABLES */
#         _inited: false,
#         _properties: ['x', 'y', 'z', 'rotateX', 'rotateY', 'rotateZ', 'scaleX', 'scaleY', 'scaleZ', 'scale'],
#         _requestAnimationFrame: null,
#
# 		/* PRIVATE FUNCTIONS */
#         _log: function (message) {
#             if (this.showLogs) console.log("Parallax Scroll / " + message);
#         },
#         _onScroll: function (noSmooth) {
#             var scroll = $(document).scrollTop();
#             var windowHeight = $(window).height();
#             this._log("onScroll " + scroll);
#             $("[data-parallax]").each($.proxy(function (index, el) {
#                 var $el = $(el);
#                 var properties = [];
#                 var applyProperties = false;
#                 var style = $el.data("style");
#                 if (style == undefined) {
#                     style = $el.attr("style") || "";
#                     $el.data("style", style);
#                 }
#                 var datas = [$el.data("parallax")];
#                 var iData;
#                 for (iData = 2; ; iData++) {
#                     if ($el.data("parallax" + iData)) {
#                         datas.push($el.data("parallax-" + iData));
#                     }
#                     else {
#                         break;
#                     }
#                 }
#                 var datasLength = datas.length;
#                 for (iData = 0; iData < datasLength; iData++) {
#                     var data = datas[iData];
#                     var scrollFrom = data["from-scroll"];
#                     if (scrollFrom == undefined) scrollFrom = Math.max(0, $(el).offset().top - windowHeight);
#                     scrollFrom = scrollFrom | 0;
#                     var scrollDistance = data["distance"];
#                     var scrollTo = data["to-scroll"];
#                     if (scrollDistance == undefined && scrollTo == undefined) scrollDistance = windowHeight;
#                     scrollDistance = Math.max(scrollDistance | 0, 1);
#                     var easing = data["easing"];
#                     var easingReturn = data["easing-return"];
#                     if (easing == undefined || !$.easing || !$.easing[easing]) easing = null;
#                     if (easingReturn == undefined || !$.easing || !$.easing[easingReturn]) easingReturn = easing;
#                     if (easing) {
#                         var totalTime = data["duration"];
#                         if (totalTime == undefined) totalTime = scrollDistance;
#                         totalTime = Math.max(totalTime | 0, 1);
#                         var totalTimeReturn = data["duration-return"];
#                         if (totalTimeReturn == undefined) totalTimeReturn = totalTime;
#                         scrollDistance = 1;
#                         var currentTime = $el.data("current-time");
#                         if (currentTime == undefined) currentTime = 0;
#                     }
#                     if (scrollTo == undefined) scrollTo = scrollFrom + scrollDistance;
#                     scrollTo = scrollTo | 0;
#                     var smoothness = data["smoothness"];
#                     if (smoothness == undefined) smoothness = 30;
#                     smoothness = smoothness | 0;
#                     if (noSmooth || smoothness == 0) smoothness = 1;
#                     smoothness = smoothness | 0;
#                     var scrollCurrent = scroll;
#                     scrollCurrent = Math.max(scrollCurrent, scrollFrom);
#                     scrollCurrent = Math.min(scrollCurrent, scrollTo);
#                     if (easing) {
#                         if ($el.data("sens") == undefined) $el.data("sens", "back");
#                         if (scrollCurrent > scrollFrom) {
#                             if ($el.data("sens") == "back") {
#                                 currentTime = 1;
#                                 $el.data("sens", "go");
#                             }
#                             else {
#                                 currentTime++;
#                             }
#                         }
#                         if (scrollCurrent < scrollTo) {
#                             if ($el.data("sens") == "go") {
#                                 currentTime = 1;
#                                 $el.data("sens", "back");
#                             }
#                             else {
#                                 currentTime++;
#                             }
#                         }
#                         if (noSmooth) currentTime = totalTime;
#                         $el.data("current-time", currentTime);
#                     }
#                     this._properties.map($.proxy(function (prop) {
#                         var defaultProp = 0;
#                         var to = data[prop];
#                         if (to == undefined) return;
#                         if (prop == "scale" || prop == "scaleX" || prop == "scaleY" || prop == "scaleZ") {
#                             defaultProp = 1;
#                         }
#                         else {
#                             to = to | 0;
#                         }
#                         var prev = $el.data("_" + prop);
#                         if (prev == undefined) prev = defaultProp;
#                         var next = ((to - defaultProp) * ((scrollCurrent - scrollFrom) / (scrollTo - scrollFrom))) + defaultProp;
#                         var val = prev + (next - prev) / smoothness;
#                         if (easing && currentTime > 0 && currentTime <= totalTime) {
#                             var from = defaultProp;
#                             if ($el.data("sens") == "back") {
#                                 from = to;
#                                 to = -to;
#                                 easing = easingReturn;
#                                 totalTime = totalTimeReturn;
#                             }
#                             val = $.easing[easing](null, currentTime, from, to, totalTime);
#                         }
#                         val = Math.ceil(val * this.round) / this.round;
#                         if (val == prev && next == to) val = to;
#                         if (!properties[prop]) properties[prop] = 0;
#                         properties[prop] += val;
#                         if (prev != properties[prop]) {
#                             $el.data("_" + prop, properties[prop]);
#                             applyProperties = true;
#                         }
#                     }, this));
#                 }
#                 if (applyProperties) {
#                     if (properties["z"] != undefined) {
#                         var perspective = data["perspective"];
#                         if (perspective == undefined) perspective = 800;
#                         var $parent = $el.parent();
#                         if (!$parent.data("style")) $parent.data("style", $parent.attr("style") || "");
#                         $parent.attr("style", "perspective:" + perspective + "px; -webkit-perspective:" + perspective + "px; " + $parent.data("style"));
#                     }
#                     if (properties["scaleX"] == undefined) properties["scaleX"] = 1;
#                     if (properties["scaleY"] == undefined) properties["scaleY"] = 1;
#                     if (properties["scaleZ"] == undefined) properties["scaleZ"] = 1;
#                     if (properties["scale"] != undefined) {
#                         properties["scaleX"] *= properties["scale"];
#                         properties["scaleY"] *= properties["scale"];
#                         properties["scaleZ"] *= properties["scale"];
#                     }
#                     var translate3d = "translate3d(" + (properties["x"] ? properties["x"] : 0) + "px, " + (properties["y"] ? properties["y"] : 0) + "px, " + (properties["z"] ? properties["z"] : 0) + "px)";
#                     var rotate3d = "rotateX(" + (properties["rotateX"] ? properties["rotateX"] : 0) + "deg) rotateY(" + (properties["rotateY"] ? properties["rotateY"] : 0) + "deg) rotateZ(" + (properties["rotateZ"] ? properties["rotateZ"] : 0) + "deg)";
#                     var scale3d = "scaleX(" + properties["scaleX"] + ") scaleY(" + properties["scaleY"] + ") scaleZ(" + properties["scaleZ"] + ")";
#                     var cssTransform = translate3d + " " + rotate3d + " " + scale3d + ";";
#                     this._log(cssTransform);
#                     $el.attr("style", "transform:" + cssTransform + " -webkit-transform:" + cssTransform + " " + style);
#                 }
#             }, this));
#             if (window.requestAnimationFrame) {
#                 window.requestAnimationFrame($.proxy(this._onScroll, this, false));
#             }
#             else {
#                 this._requestAnimationFrame($.proxy(this._onScroll, this, false));
#             }
#         }
#     }
#   </script>
#  </body>
# </html>

# %% [markdown]
# ---

# %% [markdown]
# # <font color=green> SAIBA MAIS SOBRE MIM

# %% [markdown]
# ### Conheça meu trabalho
#
# <a href="https://www.joviano.com">
# <img src="https://raw.githubusercontent.com/jovianosilveira/img/master/joviano-silveira-site-logo.png" alt="joviano.com" width="5%">
# </a>
#
# <a href="https://www.youtube.com/jovianosilveira">
# <img src="https://github.com/jovianosilveira/img/blob/master/joviano-silveira-youtube-logo.png?raw=true" alt="joviano.com" width="5%">
# </a>
#
# <a href="http://www.linkedin.com/in/jovianosilveira">
# <img src="https://github.com/jovianosilveira/img/blob/master/joviano-silveira-linkedin-logo.png?raw=true" alt="joviano.com" width="5%">
# </a>
#
# <a href="https://www.instagram.com/jovi.silveira">
# <img src="https://github.com/jovianosilveira/img/blob/master/joviano-silveira-instagram-logo.png?raw=true" alt="joviano.com" width="5%">
# </a>
#
# <a href="https://www.facebook.com/jovi.silveira.cursos">
# <img src="https://github.com/jovianosilveira/img/blob/master/joviano-silveira-facebook-logo.png?raw=true" alt="joviano.com" width="5%">
# </a>
